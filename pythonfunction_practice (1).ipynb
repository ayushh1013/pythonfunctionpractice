# %%
def ayush(x,y):
    return x + y

x=2
y=3
print(ayush(x,y))
# Out:
# 5

# %%
list1 =  [1,23,33]
result = list(map(lambda x: x*x, list1))
print(result)
# Out:
# [1, 529, 1089]

# %%
# zip function
name = ['ayush','drishti']
bed = ['w1','w2']

fee_status = ['paid','paid']

all_details = list(zip(name,bed,fee_status))
print(all_details)
# Out:
# [('ayush', 'w1', 'paid'), ('drishti', 'w2', 'paid')]

# %%
x = 1
for i in range(5):
    x*=1

print(x)
# Out:
# 1
